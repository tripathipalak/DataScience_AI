# %%
fruits = ["apple","banana", "cherry" , "lichi"]
cord = (10.2,20.5)

student = {"name":"palak" , "age":22}
unique_name = {1,2,3,4,5}

fruits.append("mango")

print(fruits)

print(cord)
print(student["name"])
# Out:
# ['apple', 'banana', 'cherry', 'lichi', 'mango']
# (10.2, 20.5)
# palak

# %%
# Create a dictionary representing a product with keys 
product = {"name":"Toothbrush",
           "brand":"Sensodyne",
           "price":30,
           "tags":["dental", "soft bristles"]
           }
# add a new tag
product["tags"].append("eco-friendly")


# apply 10% discount 
product["price"] = product["price"] * 0.9
print(f"Product:{product["name"]}, Price after discount:{product["price"]}, Tags:{product["tags"]}")
# Out:
# Product:Toothbrush, Price after discount:27.0, Tags:['dental', 'soft bristles', 'eco-friendly']
