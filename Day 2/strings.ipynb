# %%
text ="python programming"
print (text.upper()) 
print (text.lower())
print (text.replace("Python","C"))
print (text.split())
print(text[0:6])
print (len(text))
# Out:
# PYTHON PROGRAMMING
# python programming
# python programming
# ['python', 'programming']
# python
# 18
